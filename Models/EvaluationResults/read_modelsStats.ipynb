# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Unary

# %%
import pickle

unary = None
unaryPerTag = None


with open("/content/resultsUnaryConstraintsjustparams.txt","rb") as f:
  unary = pickle.load(f)


with open("/content/resultsperTagUnaryConstraintsjustparams.txt","rb") as f:
  unaryPerTag = pickle.load(f)

# %%
unary
# Out:
# {'ent_type': {'correct': 267,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 1,
#   'possible': 267,
#   'actual': 268,
#   'precision': 0.996268656716418,
#   'recall': 1.0,
#   'f1': 0.9981308411214954},
#  'partial': {'correct': 266,
#   'incorrect': 0,
#   'partial': 1,
#   'missed': 0,
#   'spurious': 1,
#   'possible': 267,
#   'actual': 268,
#   'precision': 0.9944029850746269,
#   'recall': 0.99812734082397,
#   'f1': 0.9962616822429907},
#  'strict': {'correct': 266,
#   'incorrect': 1,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 1,
#   'possible': 267,
#   'actual': 268,
#   'precision': 0.9925373134328358,
#   'recall': 0.9962546816479401,
#   'f1': 0.9943925233644859},
#  'exact': {'correct': 266,
#   'incorrect': 1,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 1,
#   'possible': 267,
#   'actual': 268,
#   'precision': 0.9925373134328358,
#   'recall': 0.9962546816479401,
#   'f1': 0.9943925233644859}}

# %%
unaryPerTag
# Out:
# {'DESC': {'ent_type': {'correct': 147,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 1,
#    'possible': 147,
#    'actual': 148,
#    'precision': 0.9932432432432432,
#    'recall': 1.0,
#    'f1': 0.9966101694915254},
#   'partial': {'correct': 146,
#    'incorrect': 0,
#    'partial': 1,
#    'missed': 0,
#    'spurious': 1,
#    'possible': 147,
#    'actual': 148,
#    'precision': 0.9898648648648649,
#    'recall': 0.9965986394557823,
#    'f1': 0.993220338983051},
#   'strict': {'correct': 146,
#    'incorrect': 1,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 1,
#    'possible': 147,
#    'actual': 148,
#    'precision': 0.9864864864864865,
#    'recall': 0.9931972789115646,
#    'f1': 0.9898305084745763},
#   'exact': {'correct': 146,
#    'incorrect': 1,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 1,
#    'possible': 147,
#    'actual': 148,
#    'precision': 0.9864864864864865,
#    'recall': 0.9931972789115646,
# ...

# %% [markdown]
# # Binary

# %%
binary = None
binaryPerTag = None


with open("/content/resultsBinaryDatajustparams.txt","rb") as f:
  binary = pickle.load(f)


with open("/content/resultsperTagBinaryDatajustparams.txt","rb") as f:
  binaryPerTag = pickle.load(f)

# %%
binary
# Out:
# {'ent_type': {'correct': 339,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 339,
#   'actual': 339,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'partial': {'correct': 339,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 339,
#   'actual': 339,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'strict': {'correct': 339,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 339,
#   'actual': 339,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'exact': {'correct': 339,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 339,
#   'actual': 339,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0}}

# %%
binaryPerTag
# Out:
# {'DESC': {'ent_type': {'correct': 207,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 207,
#    'actual': 207,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'partial': {'correct': 207,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 207,
#    'actual': 207,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'strict': {'correct': 207,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 207,
#    'actual': 207,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'exact': {'correct': 207,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 207,
#    'actual': 207,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0}},
#  'CONST_ELMS_LEFT': {'ent_type': {'correct': 66,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
# ...

# %% [markdown]
# # DistancesUnary

# %%
distancesUnary = None
distancesUnaryPerTag = None


with open("/content/resultsDistancesUnaryjustparams.txt","rb") as f:
  distancesUnary = pickle.load(f)


with open("/content/resultsperTagDistancesUnaryjustparams.txt","rb") as f:
  distancesUnaryPerTag = pickle.load(f)

# %%
distancesUnary
# Out:
# {'ent_type': {'correct': 432,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 4,
#   'spurious': 0,
#   'possible': 436,
#   'actual': 432,
#   'precision': 1.0,
#   'recall': 0.9908256880733946,
#   'f1': 0.9953917050691244},
#  'partial': {'correct': 427,
#   'incorrect': 0,
#   'partial': 5,
#   'missed': 4,
#   'spurious': 0,
#   'possible': 436,
#   'actual': 432,
#   'precision': 0.9942129629629629,
#   'recall': 0.9850917431192661,
#   'f1': 0.9896313364055298},
#  'strict': {'correct': 427,
#   'incorrect': 5,
#   'partial': 0,
#   'missed': 4,
#   'spurious': 0,
#   'possible': 436,
#   'actual': 432,
#   'precision': 0.9884259259259259,
#   'recall': 0.9793577981651376,
#   'f1': 0.9838709677419355},
#  'exact': {'correct': 427,
#   'incorrect': 5,
#   'partial': 0,
#   'missed': 4,
#   'spurious': 0,
#   'possible': 436,
#   'actual': 432,
#   'precision': 0.9884259259259259,
#   'recall': 0.9793577981651376,
#   'f1': 0.9838709677419355}}

# %%
distancesUnaryPerTag
# Out:
# {'DESC': {'ent_type': {'correct': 258,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 4,
#    'spurious': 0,
#    'possible': 262,
#    'actual': 258,
#    'precision': 1.0,
#    'recall': 0.9847328244274809,
#    'f1': 0.9923076923076923},
#   'partial': {'correct': 254,
#    'incorrect': 0,
#    'partial': 4,
#    'missed': 4,
#    'spurious': 0,
#    'possible': 262,
#    'actual': 258,
#    'precision': 0.9922480620155039,
#    'recall': 0.9770992366412213,
#    'f1': 0.9846153846153846},
#   'strict': {'correct': 254,
#    'incorrect': 4,
#    'partial': 0,
#    'missed': 4,
#    'spurious': 0,
#    'possible': 262,
#    'actual': 258,
#    'precision': 0.9844961240310077,
#    'recall': 0.9694656488549618,
#    'f1': 0.9769230769230769},
#   'exact': {'correct': 254,
#    'incorrect': 4,
#    'partial': 0,
#    'missed': 4,
#    'spurious': 0,
#    'possible': 262,
#    'actual': 258,
#    'precision': 0.9844961240310077,
#    'recall': 0.9694656488549618,
# ...

# %% [markdown]
# # DistancesBinary

# %%
distancesBinary = None
distancesBinaryPerTag = None


with open("/content/resultsDistancesjustparams.txt","rb") as f:
  distancesBinary = pickle.load(f)


with open("/content/resultsperTagDistancesjustparams.txt","rb") as f:
  distancesBinaryPerTag = pickle.load(f)

# %%
distancesBinary
# Out:
# {'ent_type': {'correct': 560,
#   'incorrect': 0,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 560,
#   'actual': 560,
#   'precision': 1.0,
#   'recall': 1.0,
#   'f1': 1.0},
#  'partial': {'correct': 554,
#   'incorrect': 0,
#   'partial': 6,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 560,
#   'actual': 560,
#   'precision': 0.9946428571428572,
#   'recall': 0.9946428571428572,
#   'f1': 0.9946428571428572},
#  'strict': {'correct': 554,
#   'incorrect': 6,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 560,
#   'actual': 560,
#   'precision': 0.9892857142857143,
#   'recall': 0.9892857142857143,
#   'f1': 0.9892857142857143},
#  'exact': {'correct': 554,
#   'incorrect': 6,
#   'partial': 0,
#   'missed': 0,
#   'spurious': 0,
#   'possible': 560,
#   'actual': 560,
#   'precision': 0.9892857142857143,
#   'recall': 0.9892857142857143,
#   'f1': 0.9892857142857143}}

# %%
distancesBinaryPerTag
# Out:
# {'DESC': {'ent_type': {'correct': 336,
#    'incorrect': 0,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 336,
#    'actual': 336,
#    'precision': 1.0,
#    'recall': 1.0,
#    'f1': 1.0},
#   'partial': {'correct': 330,
#    'incorrect': 0,
#    'partial': 6,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 336,
#    'actual': 336,
#    'precision': 0.9910714285714286,
#    'recall': 0.9910714285714286,
#    'f1': 0.9910714285714286},
#   'strict': {'correct': 330,
#    'incorrect': 6,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 336,
#    'actual': 336,
#    'precision': 0.9821428571428571,
#    'recall': 0.9821428571428571,
#    'f1': 0.9821428571428571},
#   'exact': {'correct': 330,
#    'incorrect': 6,
#    'partial': 0,
#    'missed': 0,
#    'spurious': 0,
#    'possible': 336,
#    'actual': 336,
#    'precision': 0.9821428571428571,
#    'recall': 0.9821428571428571,
#    'f1': 0.9821428571428571}},
# ...
